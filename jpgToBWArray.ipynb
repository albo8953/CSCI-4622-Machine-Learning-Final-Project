# %%
import numpy as np
from tempfile import TemporaryFile
outfile = TemporaryFile()

X_train = []

from PIL import Image
chords = ['C', 'D', 'G', 'Em']
# Cody
for c in chords:
    for i in range(5):
        image = Image.open('cody_' + c + '_BW' + str(i+1) + '.jpg')

        # Convert image to Black and White
        #     True = White
        #     False = Black
        image = image.convert('1')

        numpydata = np.asarray(image)
        # 2D to 1D array
        oneD = numpydata.flatten()
        zeroOnes = np.zeros(1024)
        for i in range(len(oneD)):
            if oneD[i]:
                zeroOnes[i] = 0
            else:
                zeroOnes[i] = 1
        X_train.append(zeroOnes)
        print(zeroOnes)
        
# Jason
for c in chords:
    for i in range(5):
        image = Image.open('jason_' + c + '_BW' + str(i+1) + '.jpg')

        # Convert image to Black and White
        #     True = White
        #     False = Black
        image = image.convert('1')

        numpydata = np.asarray(image)
        # 2D to 1D array
        oneD = numpydata.flatten()
        zeroOnes = np.zeros(1024)
        for i in range(len(oneD)):
            if oneD[i]:
                zeroOnes[i] = 0
            else:
                zeroOnes[i] = 1
        X_train.append(zeroOnes)
        
# Troy
for c in chords:
    for i in range(5):
        image = Image.open('troy_' + c + '_BW' + str(i+1) + '.jpg')

        # Convert image to Black and White
        #     True = White
        #     False = Black
        image = image.convert('1')

        numpydata = np.asarray(image)
        # 2D to 1D array
        oneD = numpydata.flatten()
        zeroOnes = np.zeros(1024)
        for i in range(len(oneD)):
            if oneD[i]:
                zeroOnes[i] = 0
            else:
                zeroOnes[i] = 1
        X_train.append(zeroOnes)
        
# Zoe
for c in chords:
    for i in range(5):
        image = Image.open('zoe_' + c + '_BW' + str(i+1) + '.jpg')

        # Convert image to Black and White
        #     True = White
        #     False = Black
        image = image.convert('1')

        numpydata = np.asarray(image)
        # 2D to 1D array
        oneD = numpydata.flatten()
        zeroOnes = np.zeros(1024)
        for i in range(len(oneD)):
            if oneD[i]:
                zeroOnes[i] = 0
            else:
                zeroOnes[i] = 1
        X_train.append(zeroOnes)

X_train = np.asarray(X_train)
print(X_train.shape)

Y_train = []
for i in range (4):
    for y in range(20):
        if y < 5:
            Y_train.append([1,0,0,0])
        elif y < 10:
            Y_train.append([0,1,0,0])
        elif y < 15:
            Y_train.append([0,0,1,0])
        else:
            Y_train.append([0,0,0,1])

Y_train = np.asarray(Y_train)
print(Y_train)
